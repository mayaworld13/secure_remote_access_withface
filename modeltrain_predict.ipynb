# %%
import cv2
import numpy as np
import urllib.request
from os import listdir
from os.path import isfile, join

# %%
# Open Webcam
cap = cv2.VideoCapture(0)
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def face_detector(img, size=0.5):

    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi
# Out:
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-3-34dab6d67da0>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
print(cv2.__version__)
# Get the training data we previously made
data_path = r'C:\Users\mayan\OneDrive\Desktop\Cloud_Sec_CV_ML\maya_photos\\'
# a=listdir('d:/faces')
# print(a)
# """
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)
# 
# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)
# model=cv2.face_LBPHFaceRecognizer.create()

model = cv2.face.LBPHFaceRecognizer_create() 
# Initialize facial recognizer
#model = cv2.face_LBPHFaceRecognizer.create()
# model=cv2.f
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()

# Let's train our model 
model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained successfully")
# Out:
# 4.7.0
# Model trained successfully

# %%
while True:

    ret, frame = cap.read()

    image, face = face_detector(frame)

    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = model.predict(face)
        print(results)
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'

        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)

        if confidence > 80:
           
            cv2.putText(image, "Welcome to Maya World Mayank!!", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            
            #os.system("curl /kxzehhlpr5.execute-api.ap-south-1.amazonaws.com/test/unlock")
            
            #AI MODEL
            request_url = urllib.request.urlopen("https://nmkuctsia0.execute-api.ap-south-1.amazonaws.com/test/unlock")
            print( request_url.read())
            
            cv2.imshow('Face Recognition', image )
          

        else:
            cv2.putText(image, "i dont know", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)

            
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        request_url = urllib.request.urlopen("https://nmkuctsia0.execute-api.ap-south-1.amazonaws.com/test/lock")
        print( request_url.read())
        cv2.imshow('Face Recognition', image )
        pass

    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (92, 35.36788679597948)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (94, 35.21208944750042)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 34.59074939914583)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (94, 35.10146242748743)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 33.525323783673976)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 32.7026821599914)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 35.53982014266826)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (94, 34.87100064995033)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (92, 34.96950546676302)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (94, 36.44933879186849)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (92, 37.69030802775808)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (94, 38.48347687795488)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 34.37987694401703)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (94, 33.46077625611643)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 35.64067201962975)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (94, 33.457212907366234)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (69, 47.91143795926947)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (81, 42.40129875013065)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (83, 38.7708896124295)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (69, 32.451886762622046)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (47, 34.152056416981964)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 33.238405865477866)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (99, 35.0117866497614)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 31.343926530848023)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 43.577840141655216)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (94, 39.929679270009366)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (87, 42.21223672097043)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 38.172149909452514)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 35.97258298504978)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 39.5636216185825)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 44.68906998432523)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (35, 47.422228915920954)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (97, 40.55482985168146)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 38.43378711228296)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 39.77661983942243)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 37.68809401646244)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (48, 37.29630871776186)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 38.73362221597638)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 40.04387742564638)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 37.741969140097396)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 39.059008780066144)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 38.40264411980271)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (97, 32.490862566430735)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (97, 30.771085586377563)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (47, 33.527556924200965)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (69, 32.3289847738868)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 30.620889481814398)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 32.82123031431765)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 31.87729010658348)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (69, 31.478935967401284)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 31.365560531668155)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 32.02979760528908)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# b'{"statusCode": 200, "body": "\\"user locked\\""}'
# (35, 32.40551927786763)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (47, 33.04703713328739)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (47, 34.03825133823045)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (47, 33.31127085862081)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 31.92501648803277)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (35, 34.29609924929193)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 36.63235506887173)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 37.3400425514495)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 35.65102557837641)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 34.16034771387651)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 38.89956045419469)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 35.616309263303485)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 34.29767666895853)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 33.95461756201746)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
# (97, 35.78467465299157)
# b'{"statusCode": 200, "body": "\\"user unlocked\\""}'
